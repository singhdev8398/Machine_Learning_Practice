# %% [markdown]
# # Medical Cost Personal Datasets
#
# Dataset link:- https://www.kaggle.com/datasets/mirichoi0218/insurance

# %% [markdown]
# # About Dataset
#
#
# Columns
#
# age: age of primary beneficiary
#
# sex: insurance contractor gender, female, male
#
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# children: Number of children covered by health insurance / Number of dependents
#
# smoker: Smoking
#
# region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
# charges: Individual medical costs billed by health insurance

# %% [markdown]
# # Imported libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("insurance.csv")  # read the data set

# %%
df.head()  # top 5 rows
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape  # shape of the data
# Out:
# (1338, 7)

# %%
# information about the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# selection of num dataframe
num_df=df.select_dtypes(include=['int','float'])
num_df
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1338 rows x 4 columns]

# %%
# numerical columns
num_columns=num_df.columns
num_columns
# Out:
# Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %%
# selection of categorical dataframe
cat_df=df.select_dtypes(include=['object'])
cat_df
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
# categorical columns
cat_columns=cat_df.columns
cat_columns
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
# check the null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check the the duplicates rows
df.duplicated().sum()
# Out:
# 1

# %%
#drop the duplicate row
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# countplot of the age
plt.figure(figsize=(10,10))
sns.countplot(x=df['age'],data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
# pie plot of the sex 
plt.pie(df['sex'].value_counts().values,labels=df['sex'].value_counts().index,autopct="%.5f%%")
plt.show()

# %%
# histogram of bmi
sns.histplot(x="bmi",data=df,bins=100)  # mostly bmi is normaly distributed
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
# pair plot of the df
sns.pairplot(df,hue='sex')

# %%
# pie plot of the sex 
plt.pie(df['smoker'].value_counts().values,labels=df['smoker'].value_counts().index,autopct="%.5f%%")
plt.show()

# %%
# pie plot of the sex 
plt.pie(df['region'].value_counts().values,labels=df['region'].value_counts().index,autopct="%.5f%%")
plt.show()

# %%
# histogram in  bmi and region
sns.histplot(x="region",y='bmi',data=df)
# Out:
# <Axes: xlabel='region', ylabel='bmi'>

# %%
# barplot in region and bmi
sns.barplot(x="region",y='bmi',data=df)
# Out:
# <Axes: xlabel='region', ylabel='bmi'>

# %%
# distribution plot of the charges 
sns.displot(df['charges'])  # charges is the right skewed

# %%
# distribution plot of the charges 
sns.displot(np.log(df['charges']))

# %%
df.corr()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children   charges
# age       1.000000  0.109344  0.041536  0.298308
# bmi       0.109344  1.000000  0.012755  0.198401
# children  0.041536  0.012755  1.000000  0.067389
# charges   0.298308  0.198401  0.067389  1.000000

# %%
# box plot 
for i,j in enumerate(num_columns):
    plt.figure(figsize=(10,5))
    plt.subplot(2,4,i+1)
    sns.boxplot(df[j])
    plt.title(j)

# %%
# bmi has the outlier in both category (sex) 
sns.boxplot(y=df['bmi'],x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='bmi'>

# %%
# bmi has the outlier in all category (region) 
sns.boxplot(y=df['bmi'],x='region',data=df)
# Out:
# <Axes: xlabel='region', ylabel='bmi'>

# %%
# bmi has the outlier in both category (smoker) 
sns.boxplot(y=df['bmi'],x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
df['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
# pie plot of the children 
plt.pie(df['children'].value_counts().values,labels=df['children'].value_counts().index,autopct="%.5f%%",explode=[0,0,0,0,.3,.4])
plt.show()

# %% [markdown]
# # Outlier Handling
#
# Outliers present in [charges and bmi] columns

# %%
upper_bmi=df['bmi'].quantile(.99)
upper_bmi
# Out:
# 46.411200000000036

# %%
new_df=df[df['bmi']<upper_bmi]
new_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1323 rows x 7 columns]

# %%
sns.boxplot(new_df['bmi'])
# Out:
# <Axes: >

# %%
new_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1323 rows x 7 columns]

# %%
sns.boxplot(new_df['charges'])
# Out:
# <Axes: >

# %%
upper_charges=df['charges'].quantile(.83)
upper_charges
# Out:
# 23080.8511744

# %%
sns.boxplot(new_df[new_df['charges']<upper_charges]['charges'])
# Out:
# <Axes: >

# %%
new_df=new_df[new_df['charges']<upper_charges]

# %%
new_df.shape
# Out:
# (1098, 7)

# %%
# box plot 
for i,j in enumerate(num_columns):
    plt.figure(figsize=(10,5))
    plt.subplot(2,4,i+1)
    sns.boxplot(new_df[j])
    plt.title(j)

# %%
sns.distplot(df['charges'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\1319113370.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['charges'])
# <Axes: xlabel='charges', ylabel='Density'>

# %% [markdown]
# # Feature Engineering

# %%
new_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1098 rows x 7 columns]

# %%
new_df['sex']=new_df['sex'].map({'male':1,"female":0})
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\2796384441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sex']=new_df['sex'].map({'male':1,"female":0})

# %%
new_df['smoker']=new_df['smoker'].map({'yes':1,"no":0})
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\4290304111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['smoker']=new_df['smoker'].map({'yes':1,"no":0})

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1098 entries, 0 to 1336
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1098 non-null   int64
#  1   sex       1098 non-null   int64
#  2   bmi       1098 non-null   float64
#  3   children  1098 non-null   int64
#  4   smoker    1098 non-null   int64
#  5   region    1098 non-null   object
#  6   charges   1098 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 100.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
l_encoder=LabelEncoder()

# %%
new_df['region']=l_encoder.fit_transform(new_df['region'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_31060\1225682654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['region']=l_encoder.fit_transform(new_df['region'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1098 entries, 0 to 1336
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1098 non-null   int64
#  1   sex       1098 non-null   int64
#  2   bmi       1098 non-null   float64
#  3   children  1098 non-null   int64
#  4   smoker    1098 non-null   int64
#  5   region    1098 non-null   int32
#  6   charges   1098 non-null   float64
# dtypes: float64(2), int32(1), int64(4)
# memory usage: 96.6 KB

# %% [markdown]
# # train_test_split

# %%
y=new_df['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1098, dtype: float64

# %%
x=new_df.iloc[:,:-1]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1332   52    0  44.700         3       0       3
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
#
# [1098 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=.20,random_state=0)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((878, 6), (220, 6), (878,), (220,))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,Y_test)
# Out:
# 0.670868498196834

# %% [markdown]
# # This is complete idea of linear regression model
# if user wants to increase the accuracy then follow the given idea.
# 1. normalize the data
# 2. choose the other model regression model
# 3. hyperparameter tunning
# 4. targate feature is not normaly distributed in the dataset convert into normaly
